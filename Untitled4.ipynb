# %%
from numpy import random
x = random.randint(100)
print(x)
# Out:
# 37

# %%
from numpy import random
x = random.rand(100)
print(x)
# Out:
# [0.73982827 0.9159808  0.39095545 0.75302359 0.77806715 0.25735857
#  0.54872623 0.4872192  0.39301771 0.17286367 0.88575037 0.46201097
#  0.62731972 0.61403485 0.64778641 0.59624042 0.11361476 0.74353069
#  0.96346598 0.40960645 0.42170631 0.14541639 0.48068788 0.66084086
#  0.58195178 0.1722609  0.09626536 0.55483632 0.93408974 0.76153726
#  0.22116452 0.45370145 0.30606693 0.11574695 0.03856235 0.69884872
#  0.12246357 0.2516014  0.92050953 0.20735207 0.2389346  0.29382941
#  0.27940356 0.40422935 0.90347415 0.58438905 0.95151227 0.85176723
#  0.3304162  0.97223839 0.18324205 0.05497389 0.56170122 0.37055099
#  0.84343364 0.73223098 0.3557879  0.89682779 0.94746967 0.90914017
#  0.12986486 0.69879149 0.24609971 0.35506043 0.88805883 0.51650078
#  0.23225839 0.90279323 0.08135559 0.82276962 0.84160556 0.76809067
#  0.01766715 0.12220805 0.10534243 0.29061812 0.12636656 0.56534361
#  0.32577123 0.44794374 0.51474068 0.12711979 0.39276687 0.6812285
#  0.35547592 0.06972192 0.32335236 0.06263741 0.96294455 0.05899663
#  0.22688779 0.9339535  0.36756206 0.98351826 0.64650645 0.04698179
#  0.84880569 0.68330045 0.64379125 0.25512475]

# %%
from numpy import random

x = random.choice([1, 2, 3, 4], p=[0.1, 0.3, 0.6, 0.0],
size=(10))

print(x)
# Out:
# [3 1 3 2 2 2 3 3 3 3]

# %%
from numpy import random
x = random.choice([1, 2, 3, 4], p=[0.1, 0.3, 0.6, 0.0],
size=(2, 5))
print(x)
#output tally with probability
# Out:
# [[1 3 1 3 2]
#  [2 2 2 1 3]]

# %%
from numpy import random
x = random.choice([1, 2, 3, 4], p=[0.1, 0.3, 0.6, 0.0],
size=(3, 5))
print(x)
#output does not tally probability
# Out:
# [[3 1 3 2 2]
#  [3 3 2 2 2]
#  [2 2 3 2 3]]

# %%
from numpy import random
x = random.normal(size=(2, 3))
print(x)
# Out:
# [[-0.06460532  0.41581629  0.95666438]
#  [ 0.10333904 -0.15172595 -0.82012245]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_27580\379979050.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000), hist=True)
plt.show()
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_27580\2111837670.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=True)

# %%
from numpy import random
x = random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [7 5 5 3 4 4 4 8 5 6]
